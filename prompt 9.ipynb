# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.hist(np.random.rand(1000), bins=100)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Random numbers')
plt.savefig('Random numbers.pdf', format='pdf')
